# %% [markdown]
# # Assignment 09 Solutions

# %% [markdown]
# #### Live Link: https://public.tableau.com/app/profile/mano.vishnu/viz/09_Assignment_09/Sheet1

# %% [markdown]
# #### 1.Use the DataNation data set and find the following:-
# - Create a Filled map
# - Find the Death Rate for states and the Population for each state
# - Change the color of the filled map showing the state with high death rate with red color

# %% [markdown]
# ![1.png](attachment:1.png)
