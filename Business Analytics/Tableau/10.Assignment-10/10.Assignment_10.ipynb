# %% [markdown]
# # Assignment 10 Solutions

# %% [markdown]
# #### Live Link: https://public.tableau.com/app/profile/mano.vishnu/viz/10_Assignment_10/Sheet1

# %% [markdown]
# #### 1.Use the DataNation data set and find the following:-
# - Create separate Cities by removing the Code associated with each cities
# - Create a heirarchy of the state and city
# - Create a Filled map
# - Find the Death Rate for Cities with a ShapeCard.
# - Change the color of the shapes.

# %% [markdown]
# ![1.png](attachment:1.png)
