# %% [markdown]
# # Assignment 04 Solutions

# %% [markdown]
# #### Live Link: https://public.tableau.com/app/profile/mano.vishnu/viz/04_Assignment_04/Sheet1

# %% [markdown]
# #### 1.Death Rate in colors

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# #### 2. DR & Populations

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# #### 3.Prominent Cities with Large populations

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# #### 4.Death rate of cities

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# #### 5.Create group for Costal Cities and Create a filter on Coastal Cities and Change Map Layers

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# #### 6.Use the Global Data and Create Heirarchy with Continent with diff Popuplation With Diff Symbol

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# #### 7.Determine the Inc/Dec in Population

# %% [markdown]
# ![7.png](attachment:7.png)
