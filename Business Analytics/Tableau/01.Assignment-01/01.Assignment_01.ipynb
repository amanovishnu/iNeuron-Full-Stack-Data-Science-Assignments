# %% [markdown]
# # Assignment 01 Solutions

# %% [markdown]
# #### Live Link: https://public.tableau.com/app/profile/mano.vishnu/viz/01_Assignment_01/Sheet1

# %% [markdown]
# #### 1.Show largest selling products and also show what % of sales is coming from which regions.

# %% [markdown]
# ![2021-10-27%2015_56_38-Settings.png](attachment:2021-10-27%2015_56_38-Settings.png)

# %% [markdown]
# #### 2.Convert the chart created in previous slide to 100% staked

# %% [markdown]
# ![2021-10-27%2015_57_09-Tableau%20-%20Book1%20-%20Tableau%20license%20expires%20in%2013%20days.png](attachment:2021-10-27%2015_57_09-Tableau%20-%20Book1%20-%20Tableau%20license%20expires%20in%2013%20days.png)

# %% [markdown]
# #### 3.Create a side-by-side bar to compare Actual vs Target sales of different products.

# %% [markdown]
# ![2021-10-27%2015_57_26-Settings.png](attachment:2021-10-27%2015_57_26-Settings.png)

# %% [markdown]
# #### 4.Create a tree map to show largest selling regions

# %% [markdown]
# ![2021-10-27%2015_57_51-Settings.png](attachment:2021-10-27%2015_57_51-Settings.png)

# %% [markdown]
# #### 5.Create a packed bubble to show product sales.

# %% [markdown]
# ![2021-10-27%2015_58_18-Settings.png](attachment:2021-10-27%2015_58_18-Settings.png)

# %% [markdown]
# #### 6.Create a side by side circle chart to compare actual vs target sales of different products.

# %% [markdown]
# ![2021-10-27%2015_58_34-Tableau%20-%20Book1%20-%20Tableau%20license%20expires%20in%2013%20days.png](attachment:2021-10-27%2015_58_34-Tableau%20-%20Book1%20-%20Tableau%20license%20expires%20in%2013%20days.png)
